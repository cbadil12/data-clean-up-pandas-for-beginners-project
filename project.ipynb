# %% [markdown]
# # Basic Python Practices
#
# #### Exercise 00. Variable Declaration
#
# Define the following variables with values of your choice:
#
# - A variable that stores your name (text).
# - A variable that stores your age (integer).
# - A variable that indicates if you like programming (true or false).
# - A variable that stores your average grade (decimal number).

# %%
# Declare your variables here.

#Example
greeting = "Hello world"

# %% [markdown]
# - Create a list with your five favorite numbers and print it.

# %%
# Favorite numbers list
# Lista de números favoritos
my_five_fav=[1,2,3,4,5]
print(my_five_fav)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# - Create a dictionary that stores a student's information and print it:
#
#         - Name
#         - Age
#         - Final grade

# %%
student={"name": "Carlos Badillo","age":34,"grade": 10}
print(student)
# Out:
# {'name': 'Carlos Badillo', 'age': 34, 'grade': 10}

# %% [markdown]
# #### Exercise 01. Basic data analysis with native Python structures.
# Create a list with the grades of 5 students: [8.5, 9.2, 7.8, 8.9, 10].
#
# - Calculate the average of the grades.

# %%
#Method without libraries
#--------------------------

#Set data with grades
grades=[8.5,9.2,7.8,8.9,10]

#Aux variable to compute total
total=0

#Loop to acumulate grades
for i in grades:
    total = total + i

#Calculate average
ave_grade=total/len(grades)

print(ave_grade)
# Out:
# 8.879999999999999

# %% [markdown]
# - Find the highest and lowest grade.

# %%
#Initialize values
min_grade=grades[0]
max_grade=grades[0]

#Loop to find min and max
for i in grades:
    if i < min_grade:
        min_grade=i
    if i > max_grade:
        max_grade=i
        
print(min_grade,max_grade)
# Out:
# 7.8 10

# %% [markdown]
# # Real estate data cleaning with Pandas for efficient analysis
#
# This is a real dataset that was downloaded using web scraping techniques. The data contains records from **Fotocasa**, one of the most popular real estate websites in Spain. Please do not perform web scraping unless it is for academic purposes.
#
# The dataset was downloaded a few years ago by Henry Navarro, and no economic benefit was obtained from it.
#
# It contains thousands of real house listings published on the website www.fotocasa.com. Your goal is to extract as much information as possible with the data science knowledge you have acquired so far.
#
# Let's get started!
#
# - First, let's read and explore the dataset.

# %%
import pandas as pd

# Leer el archivo CSV
ds = pd.read_csv('assets/real_estate.csv', sep=';') # Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds # mostramos todo
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# - Display the first rows of the CSV file.

# %%
ds.head(10)
# Out:
#    Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0           1       153771986  False            ferrari 57 inmobiliaria
# 1           2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2           3       153430440  False                 look find boadilla
# 3           4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4           5       153180188  False            ferrari 57 inmobiliaria
# 5           6       153934794  False                            expimad
# 6           7       153848236  False                            expimad
# 7           8       153482331  False                            expimad
# 8           9       153885351  False                            expimad
# 9          10       153215459  False                            modesta
#
#    phone_realEstate                                       url_inmueble  rooms  \
# 0       912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0
# ...

# %% [markdown]
# Perfect, this was a small practice. Now let's begin with the real exercises!

# %% [markdown]
# #### Exercise 01. What is the most expensive house in the entire dataset? (★☆☆)
#
# Print the address and price of the selected house. For example:
#
# `The house located at Calle del Prado, Nº20 is the most expensive, and its price is 5000000 USD.`

# %%
#Find the most expensive price
max_price=ds["price"].max()

#Find the index correspoding to that price
max_index=ds.index[ds['price'] == max_price]

#Find the address correspoding to that index
max_address=ds["address"].iloc[max_index]

#Final print
print("The house located at " + max_address + " is the most expensive, and its price is " + str(max_price)+" USD")
# Out:
# 13110    The house located at El Escorial is the most e...
# Name: address, dtype: object

# %% [markdown]
# #### Exercise 02. What is the cheapest house in the dataset? (★☆☆)
#
# This exercise is similar to the previous one, except now we are looking for the house with the lowest price. Remember to print the address and price of the selected house. For example:
#
# `The house located at Calle Alcalá, Nº58 is the cheapest, and its price is 12000 USD.`

# %%
#Method A) printing all min (price = 0)
#--------------------------

#Find the cheapest price
min_price=ds["price"].min()

#Find the index correspoding to that price
min_index=ds.index[ds['price'] == min_price]

#Find the address correspoding to that index
min_address=ds["address"].iloc[min_index]

#Final print
print("The house located at " + min_address.iloc[0] + " is the cheapest, and its price is " + str(min_price)+" USD")


#--------------------------
#Method B) eluding prices = 0
#--------------------------

#Clean rows with price equal to 0
ds_clean=ds.loc[ds["price"]!=0]

#Find the cheapest price
min_price_clean=ds_clean["price"].min()

#Find the index correspoding to that price
min_index_clean=ds.index[ds['price'] == min_price_clean]

#Find the address correspoding to that index
min_address_clean=ds["address"].iloc[min_index_clean]

#Final print
print("The house located at " + min_address_clean.iloc[0] + " is the cheapest, and its price is " + str(min_price_clean)+" USD")
# Out:
# The house located at Parla is the cheapest, and its price is 0 USD
# The house located at Berlin, Coslada is the cheapest, and its price is 600 USD

# %% [markdown]
# #### Exercise 03. What is the largest and smallest house in the dataset? (★☆☆)
#
# Print the address and area of the selected houses. For example:
#
# `The largest house is located at Calle Gran Vía, Nº38, and its area is 5000 square meters.`
#
# `The smallest house is located at Calle Mayor, Nº12, and its area is 200 square meters.`
#
# This exercise is similar to the previous one, but we are looking for the largest and smallest houses based on their area.

# %%
#Find the smallest and biggest areas
area_smallest=ds["surface"].min()
area_biggest=ds["surface"].max()

#Find the indexes for the smallest and biggest areas
index_smallest=ds.index[ds["surface"]==area_smallest]
index_biggest=ds.index[ds["surface"]==area_biggest]

#Find the address correspoding to that index
address_smallest=ds["address"].iloc[index_smallest]
address_biggest=ds["address"].iloc[index_biggest]

#Final print
print("The smallest house is located at " + address_smallest + " and its area is " + str(area_smallest)+" square meters.")
print("The largest house is located at " + address_biggest + " and its area is " + str(area_biggest)+" square meters.")
# Out:
# 498    The smallest house is located at Calle Amparo,...
# Name: address, dtype: object
# 6794    The largest house is located at Sevilla la Nue...
# Name: address, dtype: object

# %% [markdown]
# #### Exercise 04. How many unique populations are in the dataset? (★☆☆)
#
# Count the number of unique populations in the 'level5' column and print the names of the populations separated by commas. For example:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
populations=ds["level5"].value_counts().index.to_list()
for i in populations:
    clean_print=clean_print+i+", "
print(clean_print)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 populations=ds["level5"].value_counts().index.to_list()
#       2 for i in populations:
# ----> 3     clean_print=clean_print+i+", "
#       4 print(clean_print)
#
# NameError: name 'clean_print' is not defined

# %% [markdown]
# #### Exercise 05. Does the dataset contain null values (NAs)? (★☆☆)
#
# Print a boolean (`True` or `False`) to check if there are null values, followed by the columns that contain NAs.

# %%
# 1) Is there any NA in the DataFrame?
has_any_NA = ds.isna().any().any()

# 2) In case we have, show the colums where NA apppears
if has_any_NA:
    cols_with_NA = ds.columns[ds.isna().any()].tolist()
    print(has_any_NA)
    print(cols_with_NA)
# Out:
# True
# ['realEstate_name', 'phone_realEstate', 'rooms', 'bathrooms', 'surface', 'description', 'level4', 'level6', 'level7', 'level8', 'zipCode', 'customZone']

# %% [markdown]
# #### Exercise 06. Remove the null values (NAs) from the dataset, if applicable (★★☆)
#
# After removing the null values, compare the size of the DataFrame before and after the removal.

# %%
#Size before removal
size_bef=ds.shape

#REMOVING ROWS
#New DataSet after removal (rows)
ds_aft=ds.dropna(axis=0)
#Size after removal
size_aft=ds_aft.shape
print("IF WE REMOVE ROWS")
print("Before: "+ str(size_bef))
print("After: "+ str(size_aft))
print("\n")

#REMOVING COLUMNS
#New DataSet after removal (columns)
ds_aft=ds.dropna(axis=1)
#Size after removal
size_aft=ds_aft.shape
print("IF WE REMOVE COLUMNS")
print("Before: "+ str(size_bef))
print("After: "+ str(size_aft))
# Out:
# IF WE REMOVE ROWS
# Before: (15335, 37)
# After: (0, 37)
#
#
# IF WE REMOVE COLUMNS
# Before: (15335, 37)
# After: (15335, 25)

# %% [markdown]
# #### Exercise 07. What is the average price in the population of "Arroyomolinos (Madrid)"? (★★☆)
#
# Print the value obtained from the 'level5' column.

# %%
ds_aux=ds[ds["level5"]=="Arroyomolinos (Madrid)"]
mean_price=ds_aux["price"].mean()
print(mean_price)
# Out:
# 294541.59854014596

# %% [markdown]
# #### Exercise 08. Plot the histogram of prices for the population of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)
#
# Print the histogram of the prices and write a brief analysis of the plot in the Markdown cell.

# %%
import matplotlib.pyplot as plt

#Calculate auxs
mean_price=ds_aux["price"].mean()
median_price=ds_aux["price"].median()
size=ds_aux["price"].size
variance=ds_aux["price"].var()
sigma=variance**0.5

diff_price=round((mean_price-median_price)/mean_price,3)
print(diff_price)

#Set the figure
plt.figure(figsize = (10, 5), facecolor="w", edgecolor="grey")
plt.hist(ds_aux["price"],bins=60, color="cyan", edgecolor="black")
plt.title("Arroyomolinos (Madrid)")
plt.xlabel("Price [USD]")
plt.ylabel("Properties [uds]")

plt.axvline(mean_price, linestyle="--", linewidth=2, color="red", label="Mean price: "+ str(round(mean_price,2)) + " USD")
plt.axvline(median_price, linestyle="--", linewidth=2, color="blue", label="Median price: "+ str(round(median_price,2)) + " USD")
plt.axvspan(mean_price - sigma, mean_price + sigma, alpha=0.25, label="Standard Deviation from mean")

plt.text(0, 16,
    "BRIEF ANALYSIS:" +
    "\n- No. properties analyzed: " + str(size) +
    "\n- Mean and median price differ by " + str(100*diff_price) + "%",
    va="top", ha="left",fontsize=9,
    bbox=dict(boxstyle="round", facecolor="cyan", edgecolor="black", alpha=0.25)
)

plt.legend()

#ax.axvline(mediana, ls=":",  lw=1)
plt.show()
# Out:
# 0.019
